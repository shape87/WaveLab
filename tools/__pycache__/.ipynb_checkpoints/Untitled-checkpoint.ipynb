# %%
import pandas as pd

df = pd.read_csv('NCCAR12248_(CRT-CS09)_2316003_barometric_pressure.csv', skiprows=4, header=None)
df[2] = df[2] / 2.9529983071415975
df[1] = [x[0:-3] for x in df[1]]
df[1] = [''.join([x[0:6],'20',x[6:]]) for x in df[1]]
df = df[::20]
df = df[[1,2]]
df

# df.to_csv(path_or_buf='joachim-air-2.csv')
# Out:
#                     1          2
# 0      10/02/15 13:00  10.066966
# 20     10/02/15 13:10  10.064070
# 40     10/02/15 13:20  10.064898
# 60     10/02/15 13:30  10.065380
# 80     10/02/15 13:40  10.063795
# 100    10/02/15 13:50  10.060830
# 120    10/02/15 14:00  10.061933
# 140    10/02/15 14:10  10.060278
# 160    10/02/15 14:20  10.056210
# 180    10/02/15 14:30  10.052074
# 200    10/02/15 14:40  10.050901
# 220    10/02/15 14:50  10.051108
# 240    10/02/15 15:00  10.048971
# 260    10/02/15 15:10  10.049591
# 280    10/02/15 15:20  10.050074
# 300    10/02/15 15:30  10.053108
# 320    10/02/15 15:40  10.051867
# 340    10/02/15 15:50  10.053315
# 360    10/02/15 16:00  10.053315
# 380    10/02/15 16:10  10.053315
# 400    10/02/15 16:20  10.056072
# 420    10/02/15 16:30  10.055797
# 440    10/02/15 16:40  10.057176
# 460    10/02/15 16:50  10.058417
# 480    10/02/15 17:00  10.055383
# 500    10/02/15 17:10  10.055176
# 520    10/02/15 17:20  10.056279
# ...

# %%
df = pd.read_csv('NCDAR12588_(CUR-CS04)_9983807_barometric_pressure.csv', skiprows=4, header=None)
df[2] = df[2] / 2.9529983071415975
df[1] = [x[0:-3] for x in df[1]]
df = df[::20]
df = df[[1,2]]
df

df.to_csv(path_or_buf='joachim-air-1.csv')
